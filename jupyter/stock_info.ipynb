# %%
from data_sources import *
import akshare as ak

code = '002104'

# %%
res = get_profile_ef(code)
res
# Out:
# 2025-08-22 22:47:38 | INFO     | datasource.efinance | ok rows=1 cols=12 elapsed=71.2ms args=('002104',) kwargs={}
#      股票代码  股票名称          净利润                 总市值                流通市值  所处行业  \
# 0  002104  恒宝股份  23935679.95  20435036442.900002  17300768115.400002  通信设备
#
#    市盈率(动)   市净率   ROE        毛利率       净利率    板块编号
# 0  213.44  9.64  1.11  29.312155  9.665555  BK0448

# %%
res2 = get_profile_em(code)
res2
# Out:
# 2025-08-22 22:12:02 | INFO     | datasource.efinance | get_profile_em ok rows=9 cols=2 elapsed=112.9ms args=('002104',) kwargs={}
#    item               value
# 0   总市值  20435036442.900002
# 1  流通市值  17300768115.400002
# 2    行业                通信设备
# 3  上市时间            20070110
# 4    最新               28.85
# 5  股票代码              002104
# 6  股票简称                恒宝股份
# 7   总股本         708320154.0
# 8   流通股         599680004.0

# %%
res3 = get_profile_xq(code)
res3
# Out:
# SZ002104
# 2025-08-22 23:06:51 | INFO     | datasource.efinance | ok rows=39 cols=2 elapsed=137.0ms args=('002104',) kwargs={}
#                             item  \
# 0              actual_controller
# 1               actual_issue_vol
# 2              actual_rc_net_amt
# 3             affiliate_industry
# 4                       chairman
# 5                    classi_name
# 6                       currency
# 7                currency_encode
# 8                district_encode
# 9                          email
# 10              established_date
# 11               executives_nums
# 12                           fax
# 13               general_manager
# 14                   issue_price
# 15          legal_representative
# 16                   listed_date
# 17       main_operation_business
# 18             office_address_cn
# 19             office_address_en
# 20  online_success_rate_of_issue
# 21               operating_scope
# 22           org_cn_introduction
# ...
