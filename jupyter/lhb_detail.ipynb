# %%
from data_sources import *

"""
东财龙虎榜的详细，传入 ‘开始-截止’ 的时间参数；
在参数时期内容，显示所有过龙虎榜的股票；
column：
- 龙虎榜成交额：指的是该股票当日上榜龙虎榜中的买入额 + 卖出额总和，即龙虎榜席位的总成交金额。
- 市场总成交额：表示该股票当日在整个市场中的总成交金额。即该股票所有交易席位的总成交额，不限于龙虎榜。
- 成交额占总成交比: （龙虎榜成交额 / 市场总成交额） × 100%
"""
res = get_lhb_detail('20250801', '20250818')
res
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# 2025-08-18 23:42:19,957 | INFO | get_lhb_detail ok rows=941 cols=21 elapsed=1055.3ms args=('20250801', '20250818') kwargs={}
#       序号      代码    名称         上榜日                   解读    收盘价      涨跌幅  \
# 0      1  000010  美丽生态  2025-08-11     2家机构买入，成功率19.38%   5.10   9.9138
# 1      2  000026   飞亚达  2025-08-14      1家机构卖出，成功率9.59%  19.63  -9.6641
# 2      3  000032  深桑达A  2025-08-01     2家机构买入，成功率45.56%  24.77   9.9911
# 3      4  000056  皇庭国际  2025-08-14     3家机构买入，成功率42.04%   2.94   7.2993
# 4      5  000056  皇庭国际  2025-08-12     浙江资金卖出，成功率39.27%   2.76 -10.0977
# ..   ...     ...   ...         ...                  ...    ...      ...
# 936  937  920088  科力股份  2025-08-12  西藏自治区资金买入，成功率30.00%  42.07   5.2276
# 937  938  920088  科力股份  2025-08-11     1家机构买入，成功率31.05%  39.98   1.4721
# 938  939  920088  科力股份  2025-08-08  西藏自治区资金买入，成功率32.13%  39.40   5.1227
# 939  940  920101  志高机械  2025-08-18  西藏自治区资金卖出，成功率31.97%  54.99  -0.2720
# ...
