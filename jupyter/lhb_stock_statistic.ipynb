# %%
from data_sources import *

res = get_lhb_stock_statistic("近六月")
res
# Out:
# C:\Users\Max\anaconda3\envs\MarketSeer\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# 2025-08-18 23:55:35,321 | INFO | get_lhb_stock_statistic ok rows=2340 cols=20 elapsed=854.7ms args=('近六月',) kwargs={}
#         序号      代码    名称       最近上榜日     收盘价      涨跌幅  上榜次数        龙虎榜净买额  \
# 0        1  002104  恒宝股份  2025-08-18   30.50   5.1362    45 -3.366693e+08
# 1        2  002165   红宝丽  2025-07-03   10.10  -6.4815    45  4.779890e+08
# 2        3  301357  北方长龙  2025-08-18  170.88  15.0165    43 -7.805921e+07
# 3        4  603072  天和磁材  2025-07-11   55.08   4.1013    41 -2.436662e+07
# 4        5  603280  南方路机  2025-08-15   56.37  -5.1010    39  2.992530e+07
# ...    ...     ...   ...         ...     ...      ...   ...           ...
# 2335  2336  300478  杭州高新  2025-02-18   16.20   4.3142     1 -3.239316e+07
# ...
