# %%
from data_sources import *

res = get_lhb_institution_stat('20250801', '20250818')
res
# Out:
# C:\Users\Max\anaconda3\envs\MarketSeer\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
#   0%|          | 0/2 [00:00<?, ?it/s]
# 2025-08-19 21:52:23,680 | INFO | get_lhb_institution_stat ok rows=540 cols=16 elapsed=899.0ms args=('20250801', '20250818') kwargs={}
#       序号      代码    名称     收盘价      涨跌幅  买方机构数  卖方机构数        机构买入总额  \
# 0      1  601606  长城军工   67.82  10.0081      2      2  1.293306e+10
# 1      2  688108  赛诺医疗   29.50  17.4831      2      2  2.984341e+09
# 2      3  300803   指南针  109.87  19.9978      1      0  4.383496e+08
# 3      4  300803   指南针  125.96  14.6446      1      1  7.190327e+08
# 4      5  688733   壹石通   32.70  17.5413      1      0  3.020397e+08
# ..   ...     ...   ...     ...      ...    ...    ...           ...
# 535  536  002837   英维克   54.75   9.3906      2      3  2.420002e+08
# ...
