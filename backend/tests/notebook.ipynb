# %%
import akshare as ak

ak1 = ak.stock_lhb_detail_em(start_date="20251031", end_date="20251031")
ak1
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#     序号      代码    名称         上榜日                解读    收盘价      涨跌幅  \
# 0    1  000592  平潭发展  2025-10-31    主力做T，成功率46.14%   7.08   9.9379
# 1    2  000599  青岛双星  2025-10-31  1家机构卖出，成功率34.16%   6.47 -10.0139
# 2    3  000609  ST中迪  2025-10-31  普通席位买入，成功率72.00%   7.25   5.0725
# 3    4  000609  ST中迪  2025-10-31     主力做T，成功率8.11%   7.25   5.0725
# 4    5  000620  盈新发展  2025-10-31  2家机构卖出，成功率30.01%   2.48 -10.1449
# ..  ..     ...   ...         ...               ...    ...      ...
# 67  68  920015  锦华新材  2025-10-31  1家机构买入，成功率35.78%  58.87   0.9258
# 68  69  920020   泰凯英  2025-10-31  1家机构卖出，成功率27.27%  19.82  -1.4911
# 69  70  920641   格利尔  2025-10-31    卖一主卖，成功率41.12%  21.69  -2.7354
# 70  71  920670   数字人  2025-10-31    买一主买，成功率36.10%  18.87   2.1104
# 71  72  920953  国子软件  2025-10-31  1家机构买入，成功率35.92%  44.70  11.7500
#
#           龙虎榜净买额        龙虎榜买入额        龙虎榜卖出额  ...        市场总成交额  净买额占总成交比  \
# ...

# %%
ak2 = ak.stock_lhb_stock_statistic_em(symbol="近一月")
ak2

# %%
ak3 = ak.stock_lh_yyb_capital()
ak3

# %%
ak4 = ak.stock_lhb_detail_daily_sina(date="20251031")
ak4
# Out:
#     序号    股票代码   股票名称     收盘价    对应值         成交量          成交额  \
# 0    1  000592   平潭发展    7.08  10.32  50916.3656  348847.2533
# 1    2  001203   大中矿业   19.50  10.32   9768.2832  190214.6566
# 2    3  002317   众生药业   19.32  10.32   7725.2240  145447.0761
# 3    4  002759   天际股份   30.84  10.32   4270.1298  130389.2521
# 4    5  002812   恩捷股份   48.52  10.32   4870.9884  235060.3811
# ..  ..     ...    ...     ...    ...         ...          ...
# 66   5  301584   建发致新   32.38  36.07   1818.5731   59769.5108
# 67   1  301292   海科新源   36.25  33.15   8755.8904  292213.2487
# 68   2  301333    诺思格   68.59  33.53   2676.0498  169330.2203
# 69   3  688095   福昕软件  107.40  43.77   2229.7936  209826.6000
# 70   1  603388  *ST元成    0.78 -12.49    146.8600     118.5100
#
#                                           指标
# 0                                涨幅偏离值达7%的证券
# 1                                涨幅偏离值达7%的证券
# 2                                涨幅偏离值达7%的证券
# ...
